# %%
# %run "./goldcommonutilities"

# %%
mergetotargetwithscd("silver.da_ecommerce_dev.customers", ['customer_id'],"gold.da_ecommerce_dev.customers_scd")

# %%
target_df = spark.read.table("gold.da_ecommerce_dev.customers_scd")
target_df.display()
